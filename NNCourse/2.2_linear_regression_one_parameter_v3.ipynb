# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Linear Regression 1D: Training One Parameter</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to create cost or criterion function using MSE (Mean Square Error).</li></ul>

# %% [markdown]
# <h2>Table of Contents</h2>
# <p>In this lab, you will train a model with PyTorch by using data that you created. The model only has one parameter: the slope.</p>
#
# <ul>
#     <li><a href="#Makeup_Data">Make Some Data</a></li>
#     <li><a href="#Model_Cost">Create the Model and Cost Function (Total Loss)</a></li>
#     <li><a href="#Train">Train the Model</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>20 min</strong></p>
#
# <hr>

# %% [markdown]
# <h2>Preparation</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab.

# %%
# These are the libraries will be used for this lab.

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The class <code>plot_diagram</code> helps us to visualize the data space and the parameter space during training and has nothing to do with PyTorch.

# %%
# The class for plotting

class plot_diagram():
    
    # Constructor
    def __init__(self, X, Y, w, stop, go = False):
        start = w.data
        self.error = []
        self.parameter = []
        print(type(X.numpy()))
        self.X = X.numpy()
       
        self.Y = Y.numpy()
        self.parameter_values = torch.arange(start, stop)
        self.Loss_function = [criterion(forward(X), Y) for w.data in self.parameter_values] 
        w.data = start
        
    # Executor
    def __call__(self, Yhat, w, error, n):
        self.error.append(error)
        self.parameter.append(w.data)
        plt.subplot(212)
        plt.plot(self.X, Yhat.detach().numpy())
        plt.plot(self.X, self.Y,'ro')
        plt.xlabel("A")
        plt.ylim(-20, 20)
        plt.subplot(211)
        plt.title("Data Space (top) Estimated Line (bottom) Iteration " + str(n))
        # Convert lists to PyTorch tensors
        parameter_values_tensor = torch.tensor(self.parameter_values)
        loss_function_tensor = torch.tensor(self.Loss_function)

        # Plot using the tensors
        plt.plot(parameter_values_tensor.numpy(), loss_function_tensor.numpy())
  
        plt.plot(self.parameter, self.error, 'ro')
        plt.xlabel("B")
        plt.figure()
    
    # Destructor
    def __del__(self):
        plt.close('all')

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Makeup_Data">Make Some Data</h2>

# %% [markdown]
# Import PyTorch library:

# %%
# Import the library PyTorch

import torch

# %% [markdown]
# Generate values from -3 to 3 that create a line with a slope of -3. This is the line you will estimate.

# %%
# Create the f(X) with a slope of -3

X = torch.arange(-3, 3, 0.1).view(-1, 1)
f = -3 * X

# %% [markdown]
# Let us plot the line.

# %%
# Plot the line with blue

plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Let us add some noise to the data in order to simulate the real data. Use <code>torch.randn(X.size())</code> to generate Gaussian noise that is the same size as <code>X</code> and has a standard deviation opf 0.1.

# %%
# Add some noise to f(X) and save it in Y
print(X.size())
print(torch.randn(X.size()).size())
Y = f + 0.1 * torch.randn(X.size())
print(Y.size())
# Out:
# torch.Size([60, 1])
# torch.Size([60, 1])
# torch.Size([60, 1])

# %% [markdown]
# Plot the <code>Y</code>:

# %%
# Plot the data points

plt.plot(X.numpy(), Y.numpy(), 'rx', label = 'Y')

plt.plot(X.numpy(), f.numpy(), label = 'f')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Model_Cost">Create the Model and Cost Function (Total Loss)</h2>

# %% [markdown]
# In this section, let us create the model and the cost function (total loss) we are going to use to train the model and evaluate the result.

# %% [markdown]
# First, define the <code>forward</code> function $y=w*x$. (We will add the bias in the next lab.)

# %%
# Create forward function for prediction

def forward(x):
    return w * x

# %% [markdown]
# Define the cost or criterion function using MSE (Mean Square Error):

# %%
# Create the MSE function for evaluate the result.

def criterion(yhat, y):
    return torch.mean((yhat - y) ** 2)

# %% [markdown]
# Define the learning rate <code>lr</code> and an empty list <code>LOSS</code> to record the loss for each iteration:

# %%
# Create Learning Rate and an empty list to record the loss for each iteration

lr = 0.1
LOSS = []

# %% [markdown]
# Now, we create a model parameter by setting the argument <code>requires_grad</code> to <code> True</code> because the system must learn it.

# %%
w = torch.tensor(-10.0, requires_grad = True)

# %% [markdown]
# Create a <code>plot_diagram</code> object to visualize the data space and the parameter space for each iteration during training:

# %%
gradient_plot = plot_diagram(X, Y, w, stop = 5)
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="Train">Train the Model</h2>

# %% [markdown]
# Let us define a function for training the model. The steps will be described in the comments.

# %%
# Define a function for train the model

def train_model(iter):
    for epoch in range (iter):
        
        # make the prediction as we learned in the last lab
        Yhat = forward(X)
        
        # calculate the iteration
        loss = criterion(Yhat,Y)
        
        # plot the diagram for us to have a better idea
        gradient_plot(Yhat, w, loss.item(), epoch)
        
        # store the loss into list
        LOSS.append(loss.item())
        
        # backward pass: compute gradient of the loss with respect to all the learnable parameters
        loss.backward()
        
        # updata parameters
        w.data = w.data - lr * w.grad.data
        print(w.data," "  ,w.grad.data)
        # zero the gradients before running the backward pass
        w.grad.data.zero_()
        print(w.grad.data)

# %% [markdown]
# Let us try to run 4 iterations of gradient descent:

# %%
# Give 4 iterations for training the model here.

train_model(10)
# Out:
# C:\Users\Nikolas Sanderson\AppData\Local\Temp\ipykernel_16220\3839385611.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   parameter_values_tensor = torch.tensor(self.parameter_values)
# tensor(-2.9921)   tensor(-0.0469)
# tensor(0.)
# tensor(-2.9902)   tensor(-0.0188)
# tensor(0.)
# tensor(-2.9894)   tensor(-0.0075)
# tensor(0.)
# tensor(-2.9891)   tensor(-0.0030)
# tensor(0.)
# tensor(-2.9890)   tensor(-0.0012)
# tensor(0.)
# tensor(-2.9890)   tensor(-0.0005)
# tensor(0.)
# tensor(-2.9890)   tensor(-0.0002)
# tensor(0.)
# tensor(-2.9889)   tensor(-7.7075e-05)
# tensor(0.)
# tensor(-2.9889)   tensor(-3.1095e-05)
# tensor(0.)
# tensor(-2.9889)   tensor(-1.2462e-05)
# tensor(0.)

# %% [markdown]
# Plot the cost for each iteration:

# %%
# Plot the loss for each iteration

plt.plot(LOSS)
plt.tight_layout()
plt.xlabel("Epoch/Iterations")
plt.ylabel("Cost")
# Out:
# Text(38.347222222222214, 0.5, 'Cost')

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h3>Practice</h3>

# %% [markdown]
# Create a new learnable parameter <code>w</code> with an initial value of -15.0.

# %%
# Practice: Create w with the inital value of -15.0

# Type your code here

w = torch.tensor(-15.0, requires_grad=True)

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!-- Your answer is below:
# w = torch.tensor(-15.0, requires_grad=True)
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Create an empty list <code>LOSS2</code>:

# %%
# Practice: Create LOSS2 list

# Type your code here

LOSS2 = []

# %% [markdown]
# Double-click <b>here</b> for the solution.
# <!-- Your answer is below:
# LOSS2 = []
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Write your own <code>my_train_model</code> function with loss list <code>LOSS2</code>. And run it with 4 iterations.

# %%
# Practice: Create your own my_train_model

gradient_plot1 = plot_diagram(X, Y, w, stop = 15)
def my_train_model(iter):
    for epoch in range (iter):
        Yhat = forward(X)
        loss = criterion(Yhat,Y)
        gradient_plot1(Yhat, w, loss.item(), epoch)
        LOSS2.append(loss)
        loss.backward()
        w.data = w.data - lr * w.grad.data
        w.grad.data.zero_()
my_train_model(4)
# Out:
# <class 'numpy.ndarray'>
# C:\Users\Nikolas Sanderson\AppData\Local\Temp\ipykernel_16220\3839385611.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   parameter_values_tensor = torch.tensor(self.parameter_values)

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# def my_train_model(iter):
#     for epoch in range (iter):
#         Yhat = forward(X)
#         loss = criterion(Yhat,Y)
#         gradient_plot1(Yhat, w, loss.item(), epoch)
#         LOSS2.append(loss)
#         loss.backward()
#         w.data = w.data - lr * w.grad.data
#         w.grad.data.zero_()
# my_train_model(4)
#     -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# Plot an overlay of the list <code>LOSS2</code> and <code>LOSS</code>.

# %%
# Practice: Plot the list LOSS2 and LOSS

# Type your code here

plt.plot(LOSS, label = "LOSS")
plt.plot(LOSS2, label = "LOSS2")
plt.tight_layout()
plt.xlabel("Epoch/Iterations")
plt.ylabel("Cost")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 6
#       1 # Practice: Plot the list LOSS2 and LOSS
#       2
#       3 # Type your code here
#       5 plt.plot(LOSS, label = "LOSS")
# ----> 6 plt.plot(LOSS2, label = "LOSS2")
#       7 plt.tight_layout()
#       8 plt.xlabel("Epoch/Iterations")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_base.py:496, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     494     y = _check_1d(xy[1])
#     495 else:
# --> 496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
#     499     self.axes.xaxis.update_units(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\cbook\__init__.py:1656, in index_of(y)
#    1654     pass
#    1655 try:
# -> 1656     y = _check_1d(y)
#    1657 except (np.VisibleDeprecationWarning, ValueError):
#    1658     # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#    1659     pass
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\cbook\__init__.py:1348, in _check_1d(x)
#    1342 # plot requires `shape` and `ndim`.  If passed an
#    1343 # object that doesn't provide them, then force to numpy array.
#    1344 # Note this will strip unit information.
#    1345 if (not hasattr(x, 'shape') or
#    1346         not hasattr(x, 'ndim') or
#    1347         len(x.shape) < 1):
# -> 1348     return np.atleast_1d(x)
#    1349 else:
#    1350     return x
#
# File <__array_function__ internals>:200, in atleast_1d(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\core\shape_base.py:65, in atleast_1d(*arys)
#      63 res = []
#      64 for ary in arys:
# ---> 65     ary = asanyarray(ary)
#      66     if ary.ndim == 0:
#      67         result = ary.reshape(1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\_tensor.py:1087, in Tensor.__array__(self, dtype)
#    1085     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1086 if dtype is None:
# -> 1087     return self.numpy()
#    1088 else:
#    1089     return self.numpy().astype(dtype, copy=False)
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# plt.plot(LOSS, label = "LOSS")
# plt.plot(LOSS2, label = "LOSS2")
# plt.tight_layout()
# plt.xlabel("Epoch/Iterations")
# plt.ylabel("Cost")
# plt.legend()
# -->

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# What does this tell you about the parameter value?

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
# the parameter value is sensitive to initialization
#     -->

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/registration/stepone?utm_source=skills_network&utm_content=in_lab_content_link&utm_id=Lab-IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork&context=cpdaas&apps=data_science_experience%2Cwatson_machine_learning"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0110EN-SkillsNetwork/Template/module%201/images/Watson_Studio.png"></a>

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# Other contributors: <a href="https://www.linkedin.com/in/michelleccarey/">Michelle Carey</a>, <a href="www.linkedin.com/in/jiahui-mavis-zhou-a4537814a">Mavis Zhou</a>

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
# -->

# %% [markdown]
# <hr>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
